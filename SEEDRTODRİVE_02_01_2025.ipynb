# %% [markdown]
# <a href="https://colab.research.google.com/github/cagribolat/SEEDR-TO-DRIVE/blob/main/SEEDRTODR%C4%B0VE_02_01_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1-First, create a folder called "Torrent" in google drive.**

# %% [markdown]
# **2-Add Google Drive**

# %% [markdown]
# ![Google_Drive_logo.jpg](data:image/jpeg;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Torrent

# %% [markdown]
# ===========================================================================

# %% [markdown]
# **3-**

# %% [markdown]
# ![Ekran görüntüsü 2025-01-02 174127.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# PASTE THE SEEDR LINK **IN THE SECTION BELOW** AND TYPE THE NAME AND FILE EXTENSION AND PRESS RUN.

# %%
# !wget "PASTE SEEDR LİNK" -O “[FİLE NAME]].[FİLE EXTENSİON]”
